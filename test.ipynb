# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data.columns
# Out:
# Index(['ID', 'generation', 'school1', 'major type', 'major1_1', 'major1_2',
#        'major_data', 'job', 'class1', 'class2', 'class3', 'class4',
#        're_registration', 'contest_award', 'nationality', 'inflow_route',
#        'whyBDA', 'what_to_gain', 'hope_for_group', 'previous_class_3',
#        'previous_class_4', 'previous_class_5', 'previous_class_6',
#        'previous_class_7', 'previous_class_8', 'major_field',
#        'desired_career_path', 'completed_semester', 'project_type',
#        'time_input', 'desired_job', 'certificate_acquisition',
#        'desired_certificate', 'desired_job_except_data', 'incumbents_level',
#        'incumbents_lecture', 'incumbents_company_level',
#        'incumbents_lecture_type', 'incumbents_lecture_scale',
#        'incumbents_lecture_scale_reason', 'interested_company',
#        'expected_domain', 'contest_participation', 'idea_contest',
#        'onedayclass_topic', 'completed'],
#       dtype='object')

# %%
# 칼럼 설명
column_descriptions = {
    'ID': '학생 ID (예: TRAIN_000, TRAIN_001)',
    'generation': '기수 (9기 등)',
    'school1': '학교 코드',
    'major type': '전공 유형 (단일 전공, 복수 전공 등)',
    'major1_1': '주 전공 1',
    'major1_2': '주 전공 2',
    'major_data': '데이터 관련 전공 여부 (True/False)',
    'job': '직업 (대학생, 직장인 등)',
    'class1': '수강 클래스 1',
    'class2': '수강 클래스 2',
    'class3': '수강 클래스 3',
    'class4': '수강 클래스 4',
    're_registration': '재등록 여부',
    'contest_award': '공모전 수상 여부',
    'nationality': '국적 (내국인, 외국인 등)',
    'inflow_route': '유입 경로 (에브리타임, 지인 추천 등)',
    'whyBDA': 'BDA 참가 이유',
    'what_to_gain': 'BDA를 통해 얻고 싶은 것',
    'hope_for_group': '그룹/강의 운영 방식에 대한 희망사항',
    'previous_class_3': '이전 3기 수강 여부',
    'previous_class_4': '이전 4기 수강 여부',
    'previous_class_5': '이전 5기 수강 여부',
    'previous_class_6': '이전 6기 수강 여부',
    'previous_class_7': '이전 7기 수강 여부',
    'previous_class_8': '이전 8기 수강 여부',
    'major_field': '관심 전공 분야',
    'desired_career_path': '희망 경력 경로 (취업, 대학원 진학 등)',
    'completed_semester': '이수한 학기 수',
    'project_type': '프로젝트 유형 (팀 프로젝트, 개인 프로젝트)',
    'time_input': '투자 시간',
    'desired_job': '희망 직무',
    'certificate_acquisition': '취득한 자격증',
    'desired_certificate': '희망 자격증',
    'desired_job_except_data': '데이터 분야 외 희망 직무',
    'incumbents_level': '현직자 경력 수준 (주니어, 시니어 등)',
    'incumbents_lecture': '현직자 강의 주제',
    'incumbents_company_level': '현직자 소속 기업 규모',
    'incumbents_lecture_type': '현직자 강의 유형',
    'incumbents_lecture_scale': '희망 강의 규모',
    'incumbents_lecture_scale_reason': '강의 규모 선택 이유',
    'interested_company': '관심 기업',
    'expected_domain': '희망 산업 분야',
    'contest_participation': '공모전 참여 여부',
    'idea_contest': '아이디어 공모전 참여',
    'onedayclass_topic': '원데이클래스 주제',
    'completed': '과정 이수 완료 여부 (0: 미완료, 1: 완료)'
}

print("="*80)
print("칼럼 설명 (총 43개)")
print("="*80)
for i, (col, desc) in enumerate(column_descriptions.items(), 1):
    print(f"{i:2d}. {col:30s} - {desc}")
print("="*80)
# Out:
# ================================================================================
# 칼럼 설명 (총 43개)
# ================================================================================
#  1. ID                             - 학생 ID (예: TRAIN_000, TRAIN_001)
#  2. generation                     - 기수 (9기 등)
#  3. school1                        - 학교 코드
#  4. major type                     - 전공 유형 (단일 전공, 복수 전공 등)
#  5. major1_1                       - 주 전공 1
#  6. major1_2                       - 주 전공 2
#  7. major_data                     - 데이터 관련 전공 여부 (True/False)
#  8. job                            - 직업 (대학생, 직장인 등)
#  9. class1                         - 수강 클래스 1
# 10. class2                         - 수강 클래스 2
# 11. class3                         - 수강 클래스 3
# 12. class4                         - 수강 클래스 4
# 13. re_registration                - 재등록 여부
# 14. contest_award                  - 공모전 수상 여부
# 15. nationality                    - 국적 (내국인, 외국인 등)
# 16. inflow_route                   - 유입 경로 (에브리타임, 지인 추천 등)
# 17. whyBDA                         - BDA 참가 이유
# 18. what_to_gain                   - BDA를 통해 얻고 싶은 것
# 19. hope_for_group                 - 그룹/강의 운영 방식에 대한 희망사항
# 20. previous_class_3               - 이전 3기 수강 여부
# 21. previous_class_4               - 이전 4기 수강 여부
# 22. previous_class_5               - 이전 5기 수강 여부
# 23. previous_class_6               - 이전 6기 수강 여부
# 24. previous_class_7               - 이전 7기 수강 여부
# 25. previous_class_8               - 이전 8기 수강 여부
# 26. major_field                    - 관심 전공 분야
# 27. desired_career_path            - 희망 경력 경로 (취업, 대학원 진학 등)
# 28. completed_semester             - 이수한 학기 수
# 29. project_type                   - 프로젝트 유형 (팀 프로젝트, 개인 프로젝트)
# 30. time_input                     - 투자 시간
# 31. desired_job                    - 희망 직무
# 32. certificate_acquisition        - 취득한 자격증
# 33. desired_certificate            - 희망 자격증
# 34. desired_job_except_data        - 데이터 분야 외 희망 직무
# 35. incumbents_level               - 현직자 경력 수준 (주니어, 시니어 등)
# 36. incumbents_lecture             - 현직자 강의 주제
# 37. incumbents_company_level       - 현직자 소속 기업 규모
# 38. incumbents_lecture_type        - 현직자 강의 유형
# 39. incumbents_lecture_scale       - 희망 강의 규모
# 40. incumbents_lecture_scale_reason - 강의 규모 선택 이유
# 41. interested_company             - 관심 기업
# 42. expected_domain                - 희망 산업 분야
# 43. contest_participation          - 공모전 참여 여부
# 44. idea_contest                   - 아이디어 공모전 참여
# 45. onedayclass_topic              - 원데이클래스 주제
# 46. completed                      - 과정 이수 완료 여부 (0: 미완료, 1: 완료)
# ================================================================================
